# %%
# Import required libraries
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
from pandas import  *
from numpy import *
from seaborn import *
from matplotlib.pyplot import *
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
# Load the dfset
df = read_csv('narrowband signals.csv')

# %%
df.head()
# Out:
#    brightpixel  narrowband  narrowbanddrd  noise  Stars Type  \
# 0         0.75        1.00           0.90   0.50           7
# 1         0.60        0.80           0.85   0.40           6
# 2         0.90        0.95           0.85   0.60           7
# 3         0.80        0.70           0.75   0.40          11
# 4         0.70        0.90           0.80   0.55           6
#
#                               Remarks  Signal Frequency(MHz)  \
# 0  Safe : signal from natural sources                   1420
# 1  Safe : signal from natural sources                   1300
# 2              Warning : Alien signal                   1500
# 3  Safe : signal from natural sources                   1367
# 4              Warning : Alien signal                   1550
#
#    Signal Duration(seconds)  Signal Origin
# 0                         5               0
# 1                         3               0
# 2                        10               0
# 3                         7               0
# ...

# %%
#df=df.drop(columns='Signal Origin')
#df=df.drop(columns='Stars Type')

# %%
df.columns
# Out:
# Index(['brightpixel', 'narrowband', 'narrowbanddrd', 'noise', 'Stars Type',
#        'Remarks', 'Signal Frequency(MHz)', 'Signal Duration(seconds)',
#        'Signal Origin '],
#       dtype='object')

# %% [markdown]
# ..........................................................................................................................................................................

# %% [markdown]
# column:  Stars type

# %% [markdown]
# 1= A type star

# %% [markdown]
# 2= B type star

# %% [markdown]
# 6 = F type star

# %% [markdown]
# 7 = G type star

# %% [markdown]
# 11 = k type star

# %% [markdown]
# ..........................................................................................................................................................................

# %% [markdown]
# column : Signal Origin

# %% [markdown]
#  0 =  signals from known entities in universe (safe)

# %% [markdown]
# 1 = Unknown signals / signals from void (Warning)

# %% [markdown]
# ..........................................................................................................................................................................

# %%
# Split features and target variable
x = df.drop(columns='Remarks')
y = df['Remarks']

# %%
x.head()
# Out:
#    brightpixel  narrowband  narrowbanddrd  noise  Stars Type  \
# 0         0.75        1.00           0.90   0.50           7
# 1         0.60        0.80           0.85   0.40           6
# 2         0.90        0.95           0.85   0.60           7
# 3         0.80        0.70           0.75   0.40          11
# 4         0.70        0.90           0.80   0.55           6
#
#    Signal Frequency(MHz)  Signal Duration(seconds)  Signal Origin
# 0                   1420                         5               0
# 1                   1300                         3               0
# 2                   1500                        10               0
# 3                   1367                         7               0
# 4                   1550                         8               0

# %%
x.columns
# Out:
# Index(['brightpixel', 'narrowband', 'narrowbanddrd', 'noise', 'Stars Type',
#        'Signal Frequency(MHz)', 'Signal Duration(seconds)', 'Signal Origin '],
#       dtype='object')

# %%
y
# Out:
# 0     Safe : signal from natural sources
# 1     Safe : signal from natural sources
# 2                 Warning : Alien signal
# 3     Safe : signal from natural sources
# 4                 Warning : Alien signal
# 5     Safe : signal from natural sources
# 6                 Warning : Alien signal
# 7     Safe : signal from natural sources
# 8     Safe : signal from natural sources
# 9                 Warning : Alien signal
# 10    Safe : signal from natural sources
# 11    Safe : signal from natural sources
# 12                Warning : Alien signal
# 13    Safe : signal from natural sources
# 14    Safe : signal from natural sources
# 15    Safe : signal from natural sources
# 16                Warning : Alien signal
# 17    Safe : signal from natural sources
# 18    Safe : signal from natural sources
# 19                Warning : Alien signal
# 20                Warning : Alien signal
# 21    Safe : signal from natural sources
# 22    Safe : signal from natural sources
# ...

# %% [markdown]
# RF

# %%
'''from sklearn.ensemble import  RandomForestClassifier
# Split df into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize Random Forest classifier
r = RandomForestClassifier(n_estimators=200, random_state=1)

# Train the classifier
r.fit(x_train, y_train)
'''
# Out:
# RandomForestClassifier(n_estimators=200, random_state=1)

# %%
'''#saving The Models
import joblib
joblib.dump(r,'RF alien signal.pkl')
'''
# Out:
# ['RF alien signal.pkl']

# %%
#loading The models anywhere

r=joblib.load('RF alien signal.pkl')

# %%
r.score(x_train,y_train)
# Out:
# 1.0

# %%
r.score(x_test,y_test)
# Out:
# 1.0

# %%
r.predict([[0.5,0.7,0.8,0.6,11,1700 ,13 ,1]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Warning : Alien signal'], dtype=object)

# %%
r.predict([[0.8,0.7,0.7,0.4,1,1489 ,4 ,1]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Safe : signal from natural sources'], dtype=object)

# %%
r.predict([[0.7,0.88,0.9,1,0.52,1440 ,4,0]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Safe : signal from natural sources'], dtype=object)

# %% [markdown]
# DT

# %%
from sklearn.tree import DecisionTreeClassifier
d=DecisionTreeClassifier(criterion='entropy')

# %%
d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
d.score(x_train,y_train)
# Out:
# 1.0

# %%
d.score(x_test,y_test)
# Out:
# 0.9

# %%
d.predict([[0.7,0.88,0.9,1,0.52,1440 ,4,0]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Warning : Alien signal'], dtype=object)

# %%
d.predict([[0.8,0.7,0.7,0.4,1,1489 ,4 ,1]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Safe : signal from natural sources'], dtype=object)

# %%
d.predict([[0.5,0.7,0.8,0.6,11,1700 ,13 ,1]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Warning : Alien signal'], dtype=object)

# %% [markdown]
# Cross validation scores

# %% [markdown]
# RF

# %%
from sklearn.model_selection import  KFold,cross_val_score

# %%
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier(n_estimators=100)
r.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
k=10
kf= KFold(n_splits=k)

# %%
score=cross_val_score(r,x,y,cv=kf)

# %%
score.mean()
# Out:
# 0.96

# %%
r.predict([[0.5,0.7,0.8,0.6,11,1700 ,13 ,1]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Warning : Alien signal'], dtype=object)

# %%
'''from sklearn.model_selection import KFold, cross_val_score

# Assuming d is your model, x is your feature set, and y is your target variable

best_k = 0
best_score = float('-inf')

for k in range(2, 50):  # Start from 2 because KFold with n_splits=1 is not valid
    kf = KFold(n_splits=k)
    score = cross_val_score(r, x, y, cv=kf)
    mean_score = score.mean()
    
    if mean_score > best_score:
        best_score = mean_score
        best_k = k

print(f'Best k: {best_k} with mean score: {best_score}')
'''
# Out:
# "from sklearn.model_selection import KFold, cross_val_score\n\n# Assuming d is your model, x is your feature set, and y is your target variable\n\nbest_k = 0\nbest_score = float('-inf')\n\nfor k in range(2, 50):  # Start from 2 because KFold with n_splits=1 is not valid\n    kf = KFold(n_splits=k)\n    score = cross_val_score(r, x, y, cv=kf)\n    mean_score = score.mean()\n    \n    if mean_score > best_score:\n        best_score = mean_score\n        best_k = k\n\nprint(f'Best k: {best_k} with mean score: {best_score}')\n"

# %% [markdown]
# DT

# %%
from sklearn.model_selection import  KFold,cross_val_score

# %%
k=48 # best score

# %%
kf= KFold(n_splits=k)

# %%
d=DecisionTreeClassifier(criterion='entropy')
d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
score=cross_val_score(d,x,y,cv=kf)

# %%
score.mean()
# Out:
# 0.9479166666666666

# %%
d.predict([[0.5,0.7,0.8,0.6,11,1700 ,13 ,1]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Warning : Alien signal'], dtype=object)

# %%
'''from sklearn.model_selection import KFold, cross_val_score

# Assuming d is your model, x is your feature set, and y is your target variable

best_k = 0
best_score = float('-inf')

for k in range(2, 50):  # Start from 2 because KFold with n_splits=1 is not valid
    kf = KFold(n_splits=k)
    score = cross_val_score(d, x, y, cv=kf)
    mean_score = score.mean()
    
    if mean_score > best_score:
        best_score = mean_score
        best_k = k

print(f'Best k: {best_k} with mean score: {best_score}')
'''
# Out:
# "from sklearn.model_selection import KFold, cross_val_score\n\n# Assuming d is your model, x is your feature set, and y is your target variable\n\nbest_k = 0\nbest_score = float('-inf')\n\nfor k in range(2, 50):  # Start from 2 because KFold with n_splits=1 is not valid\n    kf = KFold(n_splits=k)\n    score = cross_val_score(d, x, y, cv=kf)\n    mean_score = score.mean()\n    \n    if mean_score > best_score:\n        best_score = mean_score\n        best_k = k\n\nprint(f'Best k: {best_k} with mean score: {best_score}')\n"

# %% [markdown]
# Save our models(DT,RF)

# %%
#import joblib

# %%
#joblib.dump(d, "D-alien signal.pkl")

# %%
#joblib.dump(r, "RF-alien signal.pkl")

# %%
'''#saving The Models
import joblib
joblib.dump(model_name,'any_name.pkl')

#loading The models anywhere

Any_Name=joblib.load('any_name.pkl')'''
# Out:
# "#saving The Models\nimport joblib\njoblib.dump(model_name,'any_name.pkl')\n\n#loading The models anywhere\n\nAny_Name=joblib.load('any_name.pkl')"
